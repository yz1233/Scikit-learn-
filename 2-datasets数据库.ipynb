# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt

# %% [markdown]
# 导入datasets和线性回归model

# %%
loaded_data = datasets.fetch_california_housing()
data_X = loaded_data.data
data_Y = loaded_data.target
model=LinearRegression()
model.fit(data_X, data_Y)
print(model.predict(data_X[:4,:]))
print(data_Y[:4])
# Out:
# [4.13164983 3.97660644 3.67657094 3.2415985 ]
# [4.526 3.585 3.521 3.413]

# %% [markdown]
# 导入数据boston房价（boston在新版已被腰斩，只能用California做替换）
# data_X设置为基础变量 data_Y设置为目标房价
# 调用线性回归模块，传入XY
# 输出预测值和真实值（用前4个数据做演示）

# %%
X,Y = datasets.make_regression(n_samples=100,n_features=1,n_targets=1,noise=1)
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# 自己生成数据，共100个点 ，特征维数为1（自变量个数），目标维数为1（因变量个数），噪声大小为1（增加随机扰动）
