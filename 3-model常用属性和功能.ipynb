# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing

# %%
loaded_data = datasets.fetch_california_housing()
data_X = loaded_data.data
data_Y = loaded_data.target
model=LinearRegression()
model.fit(data_X, data_Y)
print(model.coef_)  #系数
print(model.intercept_)  #截距
# Out:
# [ 4.36693293e-01  9.43577803e-03 -1.07322041e-01  6.45065694e-01
#  -3.97638942e-06 -3.78654265e-03 -4.21314378e-01 -4.34513755e-01]
# -36.94192020718454

# %% [markdown]
# 上一节的代码，但输出系数和截距（权重和偏置）

# %%
print(model.get_params())
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False, 'tol': 1e-06}

# %% [markdown]
# 输出model之前定义的一些参数，是否复制输入的特征数据X(复制副本操作不影响原数据)，是否计算截距（偏置b）,用于计算的 CPU 核心数(none默认为1)，是否强制系数/权重为正数，求解器的收敛容忍度（Tolerance）（误差小于此则停止训练）

# %%
print(model.score(data_X, data_Y))  #R²
# Out:
# 0.606232685199805

# %% [markdown]
# 对modelfit出的模型进行评价
